# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/MARGINAL_WORKERS.csv')

# %%
# adding new column to the data set
df['marginal workers']=df['Worked for 3 months or more but less than 6 months -  Persons'] + df['Worked for less than 3 months - Persons']

# %%
distplot_columns = df.columns[6:]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1386 entries, 0 to 1385
# Data columns (total 70 columns):
#  #   Column                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                       --------------  -----
#  0   Table Code                                                                                                   1386 non-null   object
#  1   State Code                                                                                                   1386 non-null   object
#  2   District Code                                                                                                1386 non-null   object
#  3   Area Name                                                                                                    1386 non-null   object
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# for col in range(len(distplot_columns)-10):
#   sns.displot(df[[col]])

# %% [markdown]
# For the first column distribution plot is given below

# %%
sns.jointplot(data=df, x=distplot_columns[0], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[3], y=distplot_columns[63], kind="scatter", marginal_ticks=True)

# %%
sns.jointplot(data=df, x=distplot_columns[6], y=distplot_columns[63], kind="reg")

# %%
sns.jointplot(data=df, x=distplot_columns[9], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[12], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[15], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[18], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[21], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[24], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[27], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[30], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[33], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[36], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[39], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[42], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[45], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[48], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[51], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[54], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[57], y=distplot_columns[63], kind="scatter")

# %%
sns.jointplot(data=df, x=distplot_columns[60], y=distplot_columns[63], kind="scatter")
